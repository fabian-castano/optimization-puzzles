# %%
import pandas as pd

# %%
df = pd.read_csv('data/Appendix A_Case_AutoBatteries.csv', skiprows=1)
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#     Customer  Zip-Code              Concelho Distrito  Jan  Feb  Mar  Apr  \
# 0          1      1000                Lisboa   Lisboa   83   80   75   69
# 1          2      1100                Lisboa   Lisboa   98   85   84  114
# 2          3      1200                Lisboa   Lisboa   21   28   20   18
# 3          4      1300                Lisboa   Lisboa   32   20   41   16
# 4          5      1400                Lisboa   Lisboa  150   89   40  128
# ..       ...       ...                   ...      ...  ...  ...  ...  ...
# 57        58      8500              Portimão     Faro   40   18   50   19
# 58        59      8600                 Lagos     Faro   72   53   75   66
# 59        60      8700                 Olhão     Faro   11   10   16    5
# 60        61      8800                Tavira     Faro  117   71   84   21
# 61        62      8900  Vila Real St.António     Faro   70   67   36   91
#
#     Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# ...

# %%
df_by_city = df.groupby('Distrito').sum()
df_by_city
# Out:
#                   Customer  Zip-Code  \
# Distrito
# Aveiro                  92     12000
# Beja                   202     31000
# Braga                   75      9500
# Castelo Branco          83     12300
# Coimbra                 93     12900
# Faro                   575     84500
# Guarda                  87     12700
# Leiria                  53      8000
# Lisboa                 109     22600
# Portalegre              93     14700
# Porto                  196     25600
# Santarém                50      8600
# Setúbal                 68     10400
# Viana do Castelo        39      4900
# Viseu                   93     12200
# Évora                   45      7100
#
#                                                            Concelho   Jan  \
# Distrito
# Aveiro                             São João da MadeiraAveiroEspinho  1022
# Beja                     AljustrelAlmodovarBejaFerreira do Alentejo   416
# Braga                                                BragaGuimarães   124
# ...

# %%
# change orientation of the table with melt
# Out:
#              Distrito      Year Total
# 0              Aveiro  Customer    92
# 1                Beja  Customer   202
# 2               Braga  Customer    75
# 3      Castelo Branco  Customer    83
# 4             Coimbra  Customer    93
# ..                ...       ...   ...
# 235          Santarém       Dez  1793
# 236           Setúbal       Dez   556
# 237  Viana do Castelo       Dez   185
# 238             Viseu       Dez   545
# 239             Évora       Dez   147
#
# [240 rows x 3 columns]

# %%
df_by_city_melt = df.reset_index().melt(id_vars=['Distrito','Customer', 'Zip-Code','Concelho'], value_vars=['Jan' , 'Feb', 'Mar', 'Apr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'], var_name='Month', value_name='Sales')

df_by_city_melt
# Out:
#     Distrito  Customer  Zip-Code              Concelho Month  Sales
# 0     Lisboa         1      1000                Lisboa   Jan     83
# 1     Lisboa         2      1100                Lisboa   Jan     98
# 2     Lisboa         3      1200                Lisboa   Jan     21
# 3     Lisboa         4      1300                Lisboa   Jan     32
# 4     Lisboa         5      1400                Lisboa   Jan    150
# ..       ...       ...       ...                   ...   ...    ...
# 739     Faro        58      8500              Portimão   Dez     53
# 740     Faro        59      8600                 Lagos   Dez     45
# 741     Faro        60      8700                 Olhão   Dez     18
# 742     Faro        61      8800                Tavira   Dez     69
# 743     Faro        62      8900  Vila Real St.António   Dez     58
#
# [744 rows x 6 columns]

# %%
df_by_city_melt.groupby(['Distrito','Zip-Code']).agg({'Sales':'mean'})
# Out:
#                                 Sales
# Distrito         Zip-Code
# Aveiro           3700       56.750000
#                  3800      405.916667
#                  4500      185.833333
# Beja             7600      115.750000
#                  7700       49.833333
# ...                               ...
# Viana do Castelo 4900      120.333333
# Viseu            3500      352.000000
#                  3600      130.166667
#                  5100      492.416667
# Évora            7100      151.166667
#
# [62 rows x 1 columns]

# %%
import osmnx as ox

# get the coordinates of the districts based on the zip code
# Out:
# /Users/fcastanogira/PycharmProjects/optimization-puzzles/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
